# %% [markdown]
# # CAR PLATE DETECTOR
#
# My goal was to create an algorithm that would detect license plates on vehicles. As part of my research, I browsed the Kaggle website and selected a dataset with ready-made labels (https://www.kaggle.com/datasets/andrewmvd/car-plate-detection). I downloaded the selected dataset to the Google Colab environment. This requires installing the `opendatasets` library and generating a token (Kaggle.com -> top right corner -> Account -> Create New API Token).
#
# For more information, see: https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/?ref=ultralytics
#
# **NOTE:** Don't forget to remove emoticons from the first line in files:
# * /content/yolov5/train.py,
# * /content/yolov5/detect.py,
# * /content/yolov5/data/hyps/hyp.scratch-... .yaml,
# * /content/yolov5/models/yolov5... .yaml.
#
# Otherwise Google Colab will raise an error.

# %%
# !pip install opendatasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.64.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2022.6.15)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (6.1.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (3.0.4)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
# !rm -r /content/sample_data

# %%
import opendatasets as od

od.download("https://www.kaggle.com/datasets/andrewmvd/car-plate-detection")
# Out:
# Downloading car-plate-detection.zip to ./car-plate-detection
# 100%|██████████| 203M/203M [00:01<00:00, 107MB/s]

# %% [markdown]
# ## PREPRECESS DATASET
#
# The downloaded labels need to be decoded and parsed from XML format into a form for the YOLOv5 network. Then the processed labels and images need to be move to subfolders.

# %%
# Preparation of paths for training, test and validation set

import os

ANNOTATIONS = r"/content/car-plate-detection/annotations"
LABEL_DATASET_DIR = r"/content/car-plate-detection/annotations_txt"
IMG_DATASET_DIR = r"/content/car-plate-detection/images"

DATASET_MAIN_DIR = r"/content/car_plates"
IMAGES_DIR = r"/content/car_plates/images"
LABELS_DIR = r"/content/car_plates/labels"
TRAIN_IMG_DIR = r"/content/car_plates/images/train"
TRAIN_LABEL_DIR = r"/content/car_plates/labels/train"
TEST_IMG_DIR = r"/content/car_plates/images/test"
TEST_LABEL_DIR = r"/content/car_plates/labels/test"
VAL_IMG_DIR = r"/content/car_plates/images/val"
VAL_LABEL_DIR = r"/content/car_plates/labels/val"

LIST_OF_PATHS = [LABEL_DATASET_DIR, DATASET_MAIN_DIR, IMAGES_DIR, LABELS_DIR, 
                 TRAIN_IMG_DIR,  TRAIN_LABEL_DIR, TEST_IMG_DIR, TEST_LABEL_DIR, 
                 VAL_IMG_DIR, VAL_LABEL_DIR]

for path in LIST_OF_PATHS:
  if not os.path.exists(path):
    os.mkdir(path)

# %%
import xml.etree.ElementTree as ET

def extract_info_from_xml(xml_file: str) -> dict:
  """
  Decodes information from XML file.
  
  Args:
    xml_file (str): path to XML file.
  
  Returns:
    Decoded XML file in the form of a dictionary.
  """
  root = ET.parse(xml_file).getroot()

  # Initialise the info dict
  info_dict = {}
  info_dict['bboxes'] = []

  # Parse the XML Tree
  for elem in root:
    # Get the file name
    if elem.tag == "filename":
      info_dict['filename'] = elem.text

    # Get the image size
    elif elem.tag == "size":
      image_size = []
      for subelem in elem:
        image_size.append(int(subelem.text))

      info_dict['image_size'] = tuple(image_size)

    # Get details of the bounding box
    elif elem.tag == "object":
      bbox = {}
      for subelem in elem:
        if subelem.tag == "name":
          bbox["class"] = subelem.text

        elif subelem.tag == "bndbox":
          for subsubelem in subelem:
            bbox[subsubelem.tag] = int(subsubelem.text)
          info_dict['bboxes'].append(bbox)

  return info_dict

# %% [markdown]
# The cell below converts the data into the required format.

# %%
for annotation in os.listdir(ANNOTATIONS):
  file_name = annotation.split(".")[0]
  data_from_xml_file = extract_info_from_xml(
    os.path.join(ANNOTATIONS, annotation))

  img_width = data_from_xml_file["image_size"][0]
  img_height = data_from_xml_file["image_size"][1]
  x_min = data_from_xml_file["bboxes"][0]["xmin"]
  y_min = data_from_xml_file["bboxes"][0]["ymin"]
  x_max = data_from_xml_file["bboxes"][0]["xmax"]
  y_max = data_from_xml_file["bboxes"][0]["ymax"]

  x_center = (x_max + x_min) / 2
  y_center = (y_max + y_min) / 2
  width = (x_max - x_min) / img_width
  height = (y_max - y_min) / img_height

  x_center /= img_width
  y_center /= img_height

  with open(file=os.path.join(LABEL_DATASET_DIR, f"{file_name}.txt"), 
            mode="a", 
            encoding="utf8") as file:
    file.write(f"0 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}")

# %%
# Split the data into traning, test and validation sets
import random

DATASET = [
  element.split(".")[0] 
  for element in os.listdir("/content/car-plate-detection/annotations_txt")]

TEST_DATASET = random.sample(population=DATASET,
                             k=int(0.1 * len(DATASET)))
VAL_DATASET = random.sample(population=[element for element in DATASET 
                                        if element not in TEST_DATASET],
                            k=(int(0.1 * len(DATASET))))
TRAIN_DATASET = [element for element in DATASET 
                 if element not in TEST_DATASET 
                 if element not in VAL_DATASET]

# %%
import shutil

def split_dataset(dataset: list,
                  img_dir: str,
                  label_dir: str) -> None:
  """
  Moves selected photos and labels from the main 
  folder to subfolders.
  
  Args:
    dataset (list): list that contains file names.
    img_dir (list): Path to the folder for images.
    label_dir (list): Path to the folder for labels.
  """
  for element in dataset:
    label_path = os.path.join(LABEL_DATASET_DIR,
                              f"{element}.txt")
    img_path = os.path.join(IMG_DATASET_DIR,
                            f"{element}.png")

    shutil.move(src=label_path,
                dst=label_dir) 
    shutil.move(src=img_path,
                dst=img_dir)

# %%
split_dataset(dataset=TEST_DATASET,
     img_dir=TEST_IMG_DIR,
     label_dir=TEST_LABEL_DIR)

len(os.listdir(TEST_IMG_DIR)), len(os.listdir(TEST_LABEL_DIR))
# Out:
# (43, 43)

# %%
split_dataset(dataset=VAL_DATASET,
     img_dir=VAL_IMG_DIR,
     label_dir=VAL_LABEL_DIR)

len(os.listdir(VAL_IMG_DIR)), len(os.listdir(VAL_IMG_DIR))
# Out:
# (43, 43)

# %%
split_dataset(dataset=TRAIN_DATASET,
     img_dir=TRAIN_IMG_DIR,
     label_dir=TRAIN_LABEL_DIR)

len(os.listdir(TRAIN_IMG_DIR)), len(os.listdir(TRAIN_LABEL_DIR))
# Out:
# (347, 347)

# %% [markdown]
# ## Train YOLOv5 model

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12467, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 12467 (delta 7), reused 10 (delta 3), pack-reused 12447
# Receiving objects: 100% (12467/12467), 12.21 MiB | 30.50 MiB/s, done.
# Resolving deltas: 100% (8598/8598), done.

# %% [markdown]
# Create .yaml file that contains informations about location of datasets, number of classes and name of classes

# %%
with open(file="/content/yolov5/data/car_plates.yaml", mode="a", 
          encoding="utf8") as file:
  file.write(f"# dataset paths\n")
  file.write(f"train: {TRAIN_IMG_DIR}\n")
  file.write(f"val: {VAL_IMG_DIR}\n")
  file.write(f"test: {TEST_IMG_DIR}\n")
  file.write(f"\n# number of classes\n")
  file.write(f"nc: 1\n")
  file.write("\n# class names\n")
  file.write("names: ['cal_plates']")

# %%
# !python /content/yolov5/train.py \
  --img 640 \
  --cfg /content/yolov5/models/yolov5m.yaml \
  --hyp /content/yolov5/data/hyps/hyp.scratch-low.yaml \
  --batch 32 \
  --epochs 100 \
  --data /content/yolov5/data/car_plates.yaml \
  --weights yolov5s.pt \
  --name yolo_car_plates
# Out:
# train: weights=yolov5s.pt, cfg=/content/yolov5/models/yolov5m.yaml, data=/content/yolov5/data/car_plates.yaml, hyp=/content/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=yolo_car_plates, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-292-g0414637 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 90.9MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 270MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# YOLOv5m summary: 369 layers, 20871318 parameters, 20871318 gradients
#
# Transferred 57/481 items from yolov5s.pt
# AMP: checks passed ✅
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 79 weight (no decay), 82 weight, 82 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/car_plates/labels/train' images and labels...347 found, 0 missing, 0 empty, 0 corrupt: 100% 347/347 [00:00<00:00, 770.95it/s]
# train: New cache created: /content/car_plates/labels/train.cache
# val: Scanning '/content/car_plates/labels/val' images and labels...43 found, 0 missing, 0 empty, 0 corrupt: 100% 43/43 [00:00<00:00, 431.48it/s]
# val: New cache created: /content/car_plates/labels/val.cache
# Plotting labels to yolov5/runs/train/yolo_car_plates3/labels.jpg...
#
# AutoAnchor: 4.07 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to yolov5/runs/train/yolo_car_plates3
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/99     12.5G    0.1115   0.02652         0        51       640: 100% 11/11 [00:15<00:00,  1.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0% 0/1 [00:00<?, ?it/s]WARNING: NMS time limit 1.590s exceeded
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:02<00:00,  2.00s/it]
#                  all         43         43    0.00128      0.116    0.00078   0.000181
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/99     13.2G   0.09867   0.02484         0        51       640: 100% 11/11 [00:14<00:00,  1.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.00s/it]
#                  all         43         43    0.00116      0.349    0.00105   0.000179
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/99     13.2G   0.09299   0.02288         0        50       640: 100% 11/11 [00:14<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.03s/it]
#                  all         43         43    0.00093      0.279   0.000702   0.000129
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/99     13.2G   0.09179   0.02152         0        57       640: 100% 11/11 [00:16<00:00,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.00s/it]
#                  all         43         43    0.00101      0.302   0.000806   0.000213
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/99     13.2G   0.09019   0.02099         0        45       640: 100% 11/11 [00:14<00:00,  1.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.01it/s]
#                  all         43         43    0.00101      0.302   0.000811   0.000136
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/99     13.2G   0.08924   0.02102         0        55       640: 100% 11/11 [00:16<00:00,  1.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.04it/s]
#                  all         43         43    0.00116      0.349   0.000925   0.000158
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/99     13.2G   0.08775   0.02046         0        56       640: 100% 11/11 [00:15<00:00,  1.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.01it/s]
#                  all         43         43    0.00116      0.349   0.000911   0.000149
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/99     13.2G   0.08773   0.02033         0        57       640: 100% 11/11 [00:16<00:00,  1.52s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.02it/s]
#                  all         43         43    0.00101      0.302    0.00072    0.00014
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/99     13.2G   0.08519   0.02106         0        55       640: 100% 11/11 [00:14<00:00,  1.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.00it/s]
#                  all         43         43    0.00062      0.186   0.000396   6.47e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/99     13.2G   0.08436   0.02009         0        41       640: 100% 11/11 [00:16<00:00,  1.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.13it/s]
#                  all         43         43    0.00109      0.326    0.00258   0.000444
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/99     13.2G   0.08079   0.02082         0        52       640: 100% 11/11 [00:13<00:00,  1.26s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.06it/s]
#                  all         43         43    0.00124      0.372    0.00555    0.00115
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/99     13.2G   0.07646   0.02165         0        50       640: 100% 11/11 [00:15<00:00,  1.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.04it/s]
#                  all         43         43     0.0014      0.419    0.00232    0.00062
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/99     13.2G    0.0739   0.02127         0        45       640: 100% 11/11 [00:15<00:00,  1.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.03it/s]
#                  all         43         43    0.00132      0.163     0.0136    0.00146
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/99     13.2G   0.07247   0.02058         0        44       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.04it/s]
#                  all         43         43     0.0014      0.419    0.00348   0.000824
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      14/99     13.2G   0.07357   0.02021         0        51       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.00it/s]
#                  all         43         43     0.0134     0.0698    0.00896    0.00191
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      15/99     13.2G   0.07376   0.01968         0        37       640: 100% 11/11 [00:16<00:00,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.05it/s]
#                  all         43         43      0.048     0.0698     0.0368    0.00838
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      16/99     13.2G   0.06933   0.02016         0        53       640: 100% 11/11 [00:14<00:00,  1.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.17it/s]
#                  all         43         43       0.15      0.233     0.0611     0.0121
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      17/99     13.2G   0.06634   0.01911         0        51       640: 100% 11/11 [00:15<00:00,  1.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.28it/s]
#                  all         43         43      0.334      0.209      0.181     0.0543
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      18/99     13.2G   0.06615   0.01822         0        55       640: 100% 11/11 [00:14<00:00,  1.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.07it/s]
#                  all         43         43       0.16      0.326      0.132     0.0371
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      19/99     13.2G   0.06247   0.01771         0        58       640: 100% 11/11 [00:15<00:00,  1.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.09it/s]
#                  all         43         43      0.355      0.279      0.272     0.0782
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      20/99     13.2G   0.06416    0.0179         0        54       640: 100% 11/11 [00:14<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.14it/s]
#                  all         43         43      0.376      0.378      0.312     0.0806
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      21/99     13.2G   0.06097   0.01806         0        49       640: 100% 11/11 [00:15<00:00,  1.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.11it/s]
#                  all         43         43      0.578      0.319      0.331      0.106
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      22/99     13.2G   0.06135   0.01705         0        48       640: 100% 11/11 [00:15<00:00,  1.45s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.16it/s]
#                  all         43         43       0.53      0.372      0.437      0.132
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      23/99     13.2G   0.06086   0.01667         0        50       640: 100% 11/11 [00:15<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.09it/s]
#                  all         43         43      0.547      0.488      0.465      0.161
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      24/99     13.2G   0.05735    0.0175         0        56       640: 100% 11/11 [00:14<00:00,  1.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.20it/s]
#                  all         43         43      0.775      0.512      0.609      0.208
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      25/99     13.2G   0.05831   0.01696         0        53       640: 100% 11/11 [00:15<00:00,  1.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.18it/s]
#                  all         43         43      0.747       0.48      0.602      0.211
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      26/99     13.2G   0.05588   0.01695         0        65       640: 100% 11/11 [00:14<00:00,  1.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.852      0.512      0.599      0.198
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      27/99     13.2G   0.05619   0.01673         0        51       640: 100% 11/11 [00:16<00:00,  1.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.593      0.581      0.557      0.179
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      28/99     13.2G   0.05596   0.01657         0        55       640: 100% 11/11 [00:14<00:00,  1.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.19it/s]
#                  all         43         43      0.769      0.387      0.484      0.183
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      29/99     13.2G   0.05298   0.01522         0        44       640: 100% 11/11 [00:16<00:00,  1.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.24it/s]
#                  all         43         43      0.643      0.674      0.656       0.24
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      30/99     13.2G   0.05449   0.01508         0        54       640: 100% 11/11 [00:14<00:00,  1.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.19it/s]
#                  all         43         43      0.709      0.567      0.631      0.234
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      31/99     13.2G   0.05214   0.01579         0        47       640: 100% 11/11 [00:16<00:00,  1.48s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.12it/s]
#                  all         43         43      0.654      0.616      0.583      0.176
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      32/99     13.2G   0.05126   0.01634         0        55       640: 100% 11/11 [00:15<00:00,  1.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.18it/s]
#                  all         43         43        0.8      0.674      0.722      0.249
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      33/99     13.2G   0.05328   0.01594         0        43       640: 100% 11/11 [00:14<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.25it/s]
#                  all         43         43       0.79      0.605      0.714      0.261
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      34/99     13.2G   0.05093     0.016         0        52       640: 100% 11/11 [00:15<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.18it/s]
#                  all         43         43      0.744      0.558      0.593      0.229
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      35/99     13.2G   0.05034   0.01538         0        55       640: 100% 11/11 [00:15<00:00,  1.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43      0.818      0.651      0.725      0.303
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      36/99     13.2G    0.0508   0.01539         0        51       640: 100% 11/11 [00:14<00:00,  1.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.688      0.581      0.689      0.261
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      37/99     13.2G   0.05034   0.01478         0        59       640: 100% 11/11 [00:16<00:00,  1.51s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.27it/s]
#                  all         43         43      0.761      0.581      0.634      0.299
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      38/99     13.2G   0.04718   0.01477         0        62       640: 100% 11/11 [00:15<00:00,  1.41s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                  all         43         43      0.833      0.674      0.733      0.243
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      39/99     13.2G    0.0486   0.01501         0        38       640: 100% 11/11 [00:16<00:00,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43      0.859      0.628      0.721      0.329
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      40/99     13.2G   0.04659   0.01447         0        49       640: 100% 11/11 [00:14<00:00,  1.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.18it/s]
#                  all         43         43      0.745      0.674      0.729      0.318
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      41/99     13.2G   0.04725   0.01456         0        55       640: 100% 11/11 [00:16<00:00,  1.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.18it/s]
#                  all         43         43      0.747      0.826      0.787      0.344
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      42/99     13.2G   0.04488   0.01429         0        54       640: 100% 11/11 [00:14<00:00,  1.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.24it/s]
#                  all         43         43      0.823      0.674       0.69      0.221
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      43/99     13.2G   0.04402   0.01408         0        49       640: 100% 11/11 [00:16<00:00,  1.47s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                  all         43         43      0.753      0.568       0.58      0.194
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      44/99     13.2G   0.04712   0.01408         0        52       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43      0.726       0.74      0.763      0.295
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      45/99     13.2G   0.04513   0.01409         0        60       640: 100% 11/11 [00:16<00:00,  1.47s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.25it/s]
#                  all         43         43      0.669      0.657      0.719      0.287
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      46/99     13.2G   0.04482   0.01401         0        55       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.26it/s]
#                  all         43         43       0.81      0.694      0.783      0.349
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      47/99     13.2G   0.04305   0.01433         0        46       640: 100% 11/11 [00:15<00:00,  1.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43      0.709      0.736      0.729      0.334
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      48/99     13.2G   0.04325   0.01348         0        63       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.20it/s]
#                  all         43         43      0.792      0.674      0.775       0.35
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      49/99     13.2G    0.0429   0.01384         0        51       640: 100% 11/11 [00:15<00:00,  1.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.28it/s]
#                  all         43         43      0.816      0.723      0.801      0.367
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      50/99     13.2G   0.04404   0.01241         0        51       640: 100% 11/11 [00:14<00:00,  1.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43        0.8      0.744      0.799      0.399
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      51/99     13.2G   0.04132   0.01288         0        50       640: 100% 11/11 [00:15<00:00,  1.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.683        0.7      0.744      0.328
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      52/99     13.2G   0.04125   0.01298         0        44       640: 100% 11/11 [00:15<00:00,  1.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43       0.78      0.791      0.799      0.364
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      53/99     13.2G   0.04127   0.01305         0        56       640: 100% 11/11 [00:15<00:00,  1.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.754      0.721      0.761      0.318
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      54/99     13.2G   0.03989   0.01236         0        55       640: 100% 11/11 [00:16<00:00,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                  all         43         43      0.766      0.721      0.727      0.339
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      55/99     13.2G   0.04085   0.01276         0        50       640: 100% 11/11 [00:15<00:00,  1.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                  all         43         43      0.729      0.752      0.714      0.306
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      56/99     13.2G   0.03869   0.01229         0        59       640: 100% 11/11 [00:15<00:00,  1.39s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.811      0.698      0.759       0.34
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      57/99     13.2G   0.04048    0.0121         0        51       640: 100% 11/11 [00:16<00:00,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43      0.752      0.651      0.708      0.354
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      58/99     13.2G    0.0394    0.0122         0        52       640: 100% 11/11 [00:15<00:00,  1.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.24it/s]
#                  all         43         43      0.872      0.744      0.829      0.367
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      59/99     13.2G   0.03949   0.01238         0        50       640: 100% 11/11 [00:16<00:00,  1.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                  all         43         43      0.965       0.65      0.826      0.377
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      60/99     13.2G   0.03923   0.01215         0        51       640: 100% 11/11 [00:15<00:00,  1.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.24it/s]
#                  all         43         43      0.855      0.685      0.771      0.352
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      61/99     13.2G   0.04021    0.0127         0        57       640: 100% 11/11 [00:16<00:00,  1.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.24it/s]
#                  all         43         43      0.887      0.767      0.803      0.382
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      62/99     13.2G     0.038   0.01213         0        55       640: 100% 11/11 [00:15<00:00,  1.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.832      0.767      0.795      0.348
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      63/99     13.2G   0.03647   0.01241         0        64       640: 100% 11/11 [00:16<00:00,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.942      0.762      0.837      0.429
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      64/99     13.2G   0.03795   0.01178         0        58       640: 100% 11/11 [00:14<00:00,  1.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.869      0.774      0.833      0.431
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      65/99     13.2G   0.04015   0.01185         0        53       640: 100% 11/11 [00:15<00:00,  1.41s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.18it/s]
#                  all         43         43      0.812      0.702      0.785       0.38
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      66/99     13.2G   0.03802   0.01229         0        57       640: 100% 11/11 [00:15<00:00,  1.39s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                  all         43         43      0.892      0.744      0.834      0.417
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      67/99     13.2G   0.03852   0.01159         0        45       640: 100% 11/11 [00:16<00:00,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.20it/s]
#                  all         43         43      0.751      0.767      0.788      0.374
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      68/99     13.2G   0.03761   0.01161         0        56       640: 100% 11/11 [00:14<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.20it/s]
#                  all         43         43      0.888      0.674      0.809      0.408
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      69/99     13.2G    0.0364   0.01111         0        52       640: 100% 11/11 [00:15<00:00,  1.45s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.765      0.832       0.82      0.426
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      70/99     13.2G   0.03713   0.01174         0        53       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.25it/s]
#                  all         43         43      0.788      0.721      0.787      0.399
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      71/99     13.2G   0.03562   0.01134         0        52       640: 100% 11/11 [00:16<00:00,  1.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.799      0.831      0.847      0.457
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      72/99     13.2G   0.03623   0.01127         0        49       640: 100% 11/11 [00:14<00:00,  1.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                  all         43         43      0.827      0.778      0.817      0.408
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      73/99     13.2G   0.03531   0.01121         0        53       640: 100% 11/11 [00:16<00:00,  1.48s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.821      0.852      0.837      0.418
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      74/99     13.2G   0.03515   0.01124         0        57       640: 100% 11/11 [00:15<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.36it/s]
#                  all         43         43      0.927      0.744      0.843      0.433
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      75/99     13.2G   0.03567   0.01137         0        57       640: 100% 11/11 [00:16<00:00,  1.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.842      0.742      0.801      0.381
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      76/99     13.2G   0.03511   0.01175         0        52       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.19it/s]
#                  all         43         43       0.87      0.782      0.874      0.436
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      77/99     13.2G   0.03358   0.01068         0        45       640: 100% 11/11 [00:16<00:00,  1.52s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.25it/s]
#                  all         43         43      0.911      0.767      0.878      0.457
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      78/99     13.2G   0.03311   0.01044         0        44       640: 100% 11/11 [00:14<00:00,  1.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.20it/s]
#                  all         43         43      0.866      0.814      0.844      0.439
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      79/99     13.2G   0.03368   0.01041         0        48       640: 100% 11/11 [00:16<00:00,  1.47s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.862      0.791      0.845      0.411
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      80/99     13.2G   0.03422   0.01042         0        49       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                  all         43         43      0.908      0.744      0.827        0.4
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      81/99     13.2G   0.03311   0.01078         0        49       640: 100% 11/11 [00:16<00:00,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43       0.81       0.86      0.856      0.429
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      82/99     13.2G   0.03366   0.01116         0        46       640: 100% 11/11 [00:15<00:00,  1.41s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.903      0.721      0.838       0.41
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      83/99     13.2G   0.03267   0.01063         0        50       640: 100% 11/11 [00:16<00:00,  1.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.24it/s]
#                  all         43         43      0.768       0.86      0.839      0.443
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      84/99     13.2G   0.03174   0.01036         0        51       640: 100% 11/11 [00:14<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.24it/s]
#                  all         43         43      0.777      0.808      0.827      0.435
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      85/99     13.2G   0.03193   0.01047         0        63       640: 100% 11/11 [00:16<00:00,  1.47s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.17it/s]
#                  all         43         43      0.773      0.873       0.84      0.444
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      86/99     13.2G    0.0335   0.01102         0        61       640: 100% 11/11 [00:15<00:00,  1.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43      0.774      0.798        0.8      0.437
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      87/99     13.2G   0.03228   0.01081         0        53       640: 100% 11/11 [00:16<00:00,  1.48s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.20it/s]
#                  all         43         43      0.813      0.791      0.823      0.443
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      88/99     13.2G   0.03261   0.01033         0        58       640: 100% 11/11 [00:15<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43      0.751       0.93      0.886      0.443
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      89/99     13.2G   0.03176   0.01061         0        46       640: 100% 11/11 [00:15<00:00,  1.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.25it/s]
#                  all         43         43      0.901      0.744      0.853      0.407
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      90/99     13.2G   0.03189   0.01054         0        49       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.21it/s]
#                  all         43         43      0.784      0.929      0.894      0.447
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      91/99     13.2G    0.0311   0.01078         0        59       640: 100% 11/11 [00:16<00:00,  1.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.929      0.767       0.89      0.445
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      92/99     13.2G    0.0306   0.01014         0        56       640: 100% 11/11 [00:15<00:00,  1.39s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                  all         43         43      0.942      0.767      0.887      0.443
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      93/99     13.2G   0.03071  0.009936         0        41       640: 100% 11/11 [00:16<00:00,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43      0.943      0.763      0.884       0.43
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      94/99     13.2G   0.03058   0.01022         0        45       640: 100% 11/11 [00:15<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.24it/s]
#                  all         43         43      0.942      0.761      0.884       0.43
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      95/99     13.2G   0.02999   0.00969         0        41       640: 100% 11/11 [00:16<00:00,  1.48s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.25it/s]
#                  all         43         43      0.885      0.767      0.874      0.424
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      96/99     13.2G   0.03002   0.01044         0        50       640: 100% 11/11 [00:15<00:00,  1.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.25it/s]
#                  all         43         43      0.906      0.767      0.856      0.426
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      97/99     13.2G   0.03001  0.009912         0        58       640: 100% 11/11 [00:16<00:00,  1.47s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.28it/s]
#                  all         43         43      0.915       0.75      0.852      0.436
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      98/99     13.2G   0.03046   0.01005         0        43       640: 100% 11/11 [00:15<00:00,  1.39s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.23it/s]
#                  all         43         43      0.932      0.767      0.875      0.448
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      99/99     13.2G   0.03036  0.009626         0        56       640: 100% 11/11 [00:16<00:00,  1.48s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.25it/s]
#                  all         43         43      0.908      0.767      0.882      0.463
#
# 100 epochs completed in 0.513 hours.
# Optimizer stripped from yolov5/runs/train/yolo_car_plates3/weights/last.pt, 42.2MB
# Optimizer stripped from yolov5/runs/train/yolo_car_plates3/weights/best.pt, 42.2MB
#
# Validating yolov5/runs/train/yolo_car_plates3/weights/best.pt...
# Fusing layers...
# YOLOv5m summary: 290 layers, 20852934 parameters, 0 gradients
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.12s/it]
#                  all         43         43      0.908      0.767      0.882      0.463
# Results saved to yolov5/runs/train/yolo_car_plates3

# %% [markdown]
# Checking the detection results on my own images - hidden

# %%
# !python /content/yolov5/detect.py \
  --source /content/test_photo \
  --weights /content/yolov5/runs/train/yolo_car_plates3/weights/best.pt \
  --conf 0.5 \
  --name yolo_road_det
# Out:
# detect: weights=['/content/yolov5/runs/train/yolo_car_plates3/weights/best.pt'], source=/content/test_photo, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=yolo_road_det, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-292-g0414637 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 20852934 parameters, 0 gradients
# image 1/5 /content/test_photo/IMG_0775.JPG: 640x480 1 cal_plates, Done. (0.025s)
# image 2/5 /content/test_photo/IMG_0776.JPEG: 480x640 1 cal_plates, Done. (0.026s)
# image 3/5 /content/test_photo/IMG_0777.JPEG: 480x640 1 cal_plates, Done. (0.023s)
# image 4/5 /content/test_photo/IMG_0778.JPEG: 480x640 1 cal_plates, Done. (0.023s)
# image 5/5 /content/test_photo/IMG_0779.JPEG: 480x640 1 cal_plates, Done. (0.023s)
# Speed: 0.5ms pre-process, 24.0ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/yolo_road_det

# %%
import cv2
from google.colab.patches import cv2_imshow

path = "/content/yolov5/runs/detect/yolo_road_det"

for img in os.listdir(path):
  img_path = os.path.join(path, img)
  cv2_imshow(cv2.imread(img_path))
